# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
data=pd.read_csv("C:/Users/acer/Documents/food-coded.csv")
data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0  2.400       2          1               430           NaN             315
# 1  3.654       1          1               610           3.0             420
# 2  3.300       1          1               720           4.0             420
# 3  3.200       1          1               430           3.0             420
# 4  3.500       1          1               720           2.0             420
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
to_drop=['comfort_food_reasons',
'comfort_food','calories_day',
'diet_current','eating_changes',
'eating_changes_coded',
'father_education',
'father_profession',
'fav_cuisine',
'food_childhood',
'healthy_meal',
'ideal_diet',
'life_rewarding',
'meals_dinner_friend',
'mother_education',
'mother_profession',
'GPA',
'Gender',
'breakfast',
'calories_chicken',
'calories_scone',
'coffee',
'comfort_food_reasons_coded',
'cuisine',
'diet_current_coded',
'drink',
'eating_changes_coded1',
'fav_cuisine_coded',
'fav_food',
'fries',
'soup',
'thai_food',
'tortilla_calories',
'turkey_calories',
'type_sports',
'vitamins',
'waffle_calories',
'weight',
'grade_level',
'greek_food',
'healthy_feeling',
'ideal_diet_coded',
'italian_food',
'marital_status',
'nutritional_check',
'persian_food',
'self_perception_weight',
'indian_food',
'parents_cook']
data.drop(to_drop, inplace=True, axis=1)

# %%
data.head()
# Out:
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 0            1.0             2       1            5
# 1            1.0             4       1            4
# 2            2.0             3       2            5
# 3            1.0             2       2            3
# 4            1.0             4       1            4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cook           122 non-null    float64
#  1   eating_out     125 non-null    int64
#  2   employment     116 non-null    float64
#  3   ethnic_food    125 non-null    int64
#  4   exercise       112 non-null    float64
#  5   fruit_day      125 non-null    int64
#  6   income         124 non-null    float64
#  7   on_off_campus  124 non-null    float64
#  8   pay_meal_out   125 non-null    int64
#  9   sports         125 non-null    int64
#  10  veggies_day    125 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 10.9 KB

# %%
data['cook'].fillna(value=data['cook'].mean(), inplace=True)

# %%
data.describe()
# Out:
#              cook  eating_out  employment  ethnic_food    exercise  \
# count  125.000000   125.00000  116.000000   125.000000  112.000000
# mean     2.786885     2.56000    2.448276     3.744000    1.589286
# std      1.025714     1.13876    0.533158     1.177093    0.665137
# min      1.000000     1.00000    1.000000     1.000000    1.000000
# 25%      2.000000     2.00000    2.000000     3.000000    1.000000
# 50%      3.000000     2.00000    2.000000     4.000000    1.000000
# 75%      3.000000     3.00000    3.000000     5.000000    2.000000
# max      5.000000     5.00000    3.000000     5.000000    3.000000
#
#         fruit_day      income  on_off_campus  pay_meal_out      sports  \
# count  125.000000  124.000000     124.000000    125.000000  125.000000
# mean     4.224000    4.532258       1.322581      3.408000    1.384000
# std      0.923388    1.456332       0.681323      1.040285    0.488315
# min      1.000000    1.000000       1.000000      2.000000    1.000000
# ...

# %%
data['employment'].fillna(value=np.random.randint(2,4), inplace=True)
data['exercise'].fillna(value=np.random.randint(1,3), inplace=True)
data['on_off_campus'].fillna(method='ffill', inplace=True)
data['income'].fillna(method='ffill', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cook           125 non-null    float64
#  1   eating_out     125 non-null    int64
#  2   employment     125 non-null    float64
#  3   ethnic_food    125 non-null    int64
#  4   exercise       125 non-null    float64
#  5   fruit_day      125 non-null    int64
#  6   income         125 non-null    float64
#  7   on_off_campus  125 non-null    float64
#  8   pay_meal_out   125 non-null    int64
#  9   sports         125 non-null    int64
#  10  veggies_day    125 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 10.9 KB

# %%
import matplotlib.pyplot as plt
box=data.boxplot(figsize=(16,6), )
box.set_xticklabels(data.columns,rotation=30)
# Out:
# [Text(1, 0, 'cook'),
#  Text(2, 0, 'eating_out'),
#  Text(3, 0, 'employment'),
#  Text(4, 0, 'ethnic_food'),
#  Text(5, 0, 'exercise'),
#  Text(6, 0, 'fruit_day'),
#  Text(7, 0, 'income'),
#  Text(8, 0, 'on_off_campus'),
#  Text(9, 0, 'pay_meal_out'),
#  Text(10, 0, 'sports'),
#  Text(11, 0, 'veggies_day')]

# %%
from sklearn.cluster import KMeans

err=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(data)
    err.append(kmeans.inertia_)
plt.plot(range(1,11),err)
plt.title('Elbow Method')
plt.xlabel('No. of clusters')
plt.ylabel('error')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kmeans = KMeans(n_clusters=6)
data_labels = kmeans.fit_predict(data)
data_labels
# Out:
# array([2, 1, 1, 0, 1, 3, 1, 2, 5, 1, 4, 1, 0, 5, 1, 3, 4, 1, 2, 0, 0, 0,
#        2, 1, 5, 2, 0, 2, 0, 5, 1, 1, 1, 3, 2, 2, 5, 0, 0, 5, 0, 4, 2, 4,
#        1, 1, 1, 2, 1, 3, 4, 1, 5, 4, 1, 5, 5, 2, 1, 1, 5, 0, 5, 5, 4, 0,
#        1, 1, 1, 2, 4, 1, 1, 5, 3, 1, 3, 3, 2, 1, 0, 3, 3, 4, 1, 2, 1, 2,
#        4, 4, 2, 0, 3, 1, 1, 1, 0, 2, 5, 2, 4, 1, 1, 1, 1, 3, 4, 1, 2, 0,
#        3, 3, 5, 0, 3, 2, 4, 4, 4, 4, 1, 4, 4, 5, 0])

# %%
data['clusters'] = data_labels

# %%
data.head()
# Out:
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day  clusters
# 0            1.0             2       1            5         2
# 1            1.0             4       1            4         1
# 2            2.0             3       2            5         1
# 3            1.0             2       2            3         0
# 4            1.0             4       1            4         1

# %%
data1 = data[data.clusters == 0]
data2 = data[data.clusters == 1]
data3 = data[data.clusters == 2]
data4 = data[data.clusters == 3]
data5 = data[data.clusters == 4]
data6 = data[data.clusters == 5]

# %%
plt.scatter(data1.income, data1['eating_out'],color='black')
plt.scatter(data2.income, data2['eating_out'],color='green')
plt.scatter(data3.income, data3['eating_out'],color='blue')
plt.scatter(data4.income, data4['eating_out'], color='yellow')
plt.scatter(data5.income, data5['eating_out'], color='pink')
plt.scatter(data6.income, data6['eating_out'], color='red')

# %%
import numpy as np
import pandas as pd 
df=pd.read_csv("C:/Users/acer/Downloads/stephenshostel.csv")
df.head()
# Out:
#    meta__code  ... response__venues__location__state
# 0       200.0  ...                               NaN
# 1         NaN  ...                               NaN
# 2         NaN  ...                               NaN
# 3         NaN  ...                             Delhi
# 4         NaN  ...                             Delhi
#
# [5 rows x 30 columns]

# %%
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim
import requests
CLIENT_ID = '4T5ETI3BWAGID53KGFGLU2CFZ44AFNXTL1XO5C3A31NJAFMO'
CLIENT_SECRET = 'WXJSXNGCORCJGM4VKYOCZPN22DBKT0BDRWXOBUIWLQQ4ELA4'
VERSION = '20200226'
LIMIT = 10000

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    28.6591, 77.2232,
    30000, 
    LIMIT)

# %%
restrau = []
oth = []
for lat,lng in zip(df['response__venues__location__lat'], df['response__venues__location__lng']):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID,
    CLIENT_SECRET, VERSION, lat,lng,1000, 100)
    res = requests.get(url).json()
    venue= res['response']['groups'][0]['items']
    nearby_venue = json_normalize(venue)
    df1 = nearby_venue['venue.categories']

    g=[]
    for i in range(0,df1.size):
        g.append(df1[i][0]['icon']['prefix'].find('food'))
    co=0
    for i in g:
          if i>1:
              co+=1
    restrau.append(co)
    oth.append(len(g) - co)


df['restaurent'] = restrau
df['others'] = oth
df.head(10)
# Out:
# <ipython-input-9-a17fb181aeca>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venue = json_normalize(venue)
#    meta__code           meta__requestId  ... restaurent others
# 0       200.0  60a2d7419c93872bb962b828  ...         22      1
# 1         NaN                       NaN  ...          6      2
# 2         NaN                       NaN  ...         27      1
# 3         NaN                       NaN  ...          7      1
# 4         NaN                       NaN  ...          7      2
# 5         NaN                       NaN  ...         13      2
# 6         NaN                       NaN  ...          3      3
# 7         NaN                       NaN  ...         10     15
# 8         NaN                       NaN  ...         34     26
# 9         NaN                       NaN  ...          3      3
#
# [10 rows x 32 columns]

# %%
df=df.drop(['meta__code','meta__requestId','response__venues__id','response__venues__name','response__venues__location__labeledLatLngs__label','response__venues__location__labeledLatLngs__lat','response__venues__location__labeledLatLngs__lng','response__venues__location__distance','response__venues__location__cc','response__venues__location__country','response__venues__categories__id','response__venues__categories__name','response__venues__categories__name','response__venues__categories__pluralName','response__venues__categories__shortName','response__venues__categories__icon__prefix','response__venues__categories__icon__suffix','response__venues__categories__primary','response__venues__referralId','response__venues__hasPerk','response__venues__location__address','response__venues__location__crossStreet','response__venues__location__formattedAddress__002','response__venues__location__formattedAddress__003','response__venues__location__formattedAddress__004','response__venues__location__postalCode','response__venues__location__city','response__venues__location__state'],axis=1)

# %%
df.head(3)
# Out:
#          lat       long  ... restaurent  others
# 0  28.685738  77.211299  ...         22       1
# 1  28.690214  77.216032  ...          6       2
# 2  28.684835  77.207008  ...         27       1
#
# [3 rows x 5 columns]

# %%
df = df.rename(columns={'response__venues__location__lat': 'lat' , 'response__venues__location__lng': 'long', 'response__venues__location__formattedAddress__001': 'address'})

# %%
chars = ["[","]"]
for char in chars:
    df['address'] = df['address'].astype(str).str.replace(char, ' ')
# Out:
# <ipython-input-30-d364eaa6daa2>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['address'] = df['address'].astype(str).str.replace(char, ' ')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lat         35 non-null     float64
#  1   long        35 non-null     float64
#  2   address     35 non-null     object
#  3   restaurent  35 non-null     int64
#  4   others      35 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.5+ KB

# %%
kmeans_parameters = df[['lat','long']]

# %%
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans

# %%
error=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(kmeans_parameters)
    error.append(kmeans.inertia_)
plt.plot(range(1,11),error)
plt.title('Elbow Method')
plt.xlabel('No. of clusters')
plt.ylabel('error')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(kmeans_parameters)
# Out:
# KMeans(n_clusters=5)

# %%
labels = kmeans.predict(kmeans_parameters)
df['cluster'] = labels

# %%
df
# Out:
#           lat       long  ... others  cluster
# 0   28.685738  77.211299  ...      1        2
# 1   28.690214  77.216032  ...      2        2
# 2   28.684835  77.207008  ...      1        2
# 3   28.690431  77.217615  ...      1        2
# 4   28.691100  77.217205  ...      2        2
# 5   28.692803  77.211649  ...      2        2
# 6   28.680951  77.223083  ...      3        2
# 7   28.634231  77.239564  ...     15        4
# 8   28.625733  77.210406  ...     26        3
# 9   28.681860  77.224075  ...      3        2
# 10  28.681090  77.224649  ...      3        2
# 11  28.682877  77.200384  ...      5        2
# 12  28.686001  77.192933  ...      3        2
# 13  28.706785  77.214364  ...      3        2
# 14  28.646118  77.215922  ...     23        3
# 15  28.648936  77.191355  ...      7        3
# 16  28.640728  77.211735  ...     33        3
# 17  28.640670  77.211136  ...     29        3
# 18  28.640588  77.209355  ...     25        3
# ...

# %%
import seaborn as sns 
sns.scatterplot(x='lat', y='long', data=df, hue='cluster').set_title('clusters=5')
# Out:
# Text(0.5, 1.0, 'clusters=5')

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]
df4 = df[df.cluster == 3]
df5 = df[df.cluster == 4]

# %%
df1
# Out:
#           lat       long              address  restaurent  others  cluster
# 29  28.686968  77.307266                India           0       4        0
# 30  28.688265  77.307308   OBH (GTB Hospital)           0       3        0
# 33  28.683550  77.312595  UCMS (GTB Hospital)           4       6        0

# %%
import folium
from IPython.display import display


m = folium.Map(location=[28.685151275979585, 77.21357111294833], zoom_start=10)

# %%
for i in df1.itertuples():
    folium.Marker(location=[i.lat, i.long],
                  popup=i.address,
                  icon=folium.Icon(color='red')).add_to(m)
i=0
for i in df2.itertuples():
    folium.Marker(location=[i.lat, i.long],
                  popup=i.address,
                  icon=folium.Icon(color='blue')).add_to(m)

i=0
for i in df3.itertuples():
    folium.Marker(location=[i.lat, i.long],
                  popup=i.address,
                  icon=folium.Icon(color='purple')).add_to(m)

i=0
for i in df4.itertuples():
    folium.Marker(location=[i.lat, i.long],
                  popup=i.address,
                  icon=folium.Icon(color='green')).add_to(m)

i=0
for i in df5.itertuples():
    folium.Marker(location=[i.lat, i.long],
                  popup=i.address,
                  icon=folium.Icon(color='black')).add_to(m)

# %%
from IPython.display import HTML
HTML('<iframe src=map.html width=700 height=450></iframe>')
m.save('map.html')
# Out:
# C:\Users\acer\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
